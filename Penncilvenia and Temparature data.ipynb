# %% [markdown]
# # Date:27/02/2019

# %%
import pandas as pd
election = pd.read_csv("2012 US election results (Pennsylvania).csv")
election
# Out:
#             county state   total      Obama     Romney  winner   voters  \
# 0            Adams    PA   41973  35.482334  63.112001  Romney    61156
# 1        Allegheny    PA  614671  56.640219  42.185820   Obama   924351
# 2        Armstrong    PA   28322  30.696985  67.901278  Romney    42147
# 3           Beaver    PA   80015  46.032619  52.637630  Romney   115157
# 4          Bedford    PA   21444  22.057452  76.986570  Romney    32189
# 5            Berks    PA  163253  48.939376  49.528646  Romney   250356
# 6            Blair    PA   47631  32.575424  66.133401  Romney    85328
# 7         Bradford    PA   22501  36.847251  61.450602  Romney    40490
# 8            Bucks    PA  319407  49.966970  48.801686   Obama   435606
# 9           Butler    PA   88924  31.920516  66.816607  Romney   122762
# 10         Cambria    PA   57718  40.162514  57.978447  Romney    86988
# 11         Cameron    PA    1967  34.417895  64.260295  Romney     3651
# ...

# %%
election.head()
# Out:
#       county state   total      Obama     Romney  winner  voters    turnout  \
# 0      Adams    PA   41973  35.482334  63.112001  Romney   61156  68.632677
# 1  Allegheny    PA  614671  56.640219  42.185820   Obama  924351  66.497575
# 2  Armstrong    PA   28322  30.696985  67.901278  Romney   42147  67.198140
# 3     Beaver    PA   80015  46.032619  52.637630  Romney  115157  69.483401
# 4    Bedford    PA   21444  22.057452  76.986570  Romney   32189  66.619031
#
#       margin
# 0  27.629667
# 1  14.454399
# 2  37.204293
# 3   6.605012
# 4  54.929118

# %%
election[(election.county=="Bedford")& (election.winner)]
# Out:
#     county state  total      Obama    Romney  winner  voters    turnout  \
# 4  Bedford    PA  21444  22.057452  76.98657  Romney   32189  66.619031
#
#       margin
# 4  54.929118

# %%
election.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 67 entries, 0 to 66
# Data columns (total 9 columns):
# county     67 non-null object
# state      67 non-null object
# total      67 non-null int64
# Obama      67 non-null float64
# Romney     67 non-null float64
# winner     67 non-null object
# voters     67 non-null int64
# turnout    67 non-null float64
# margin     67 non-null float64
# dtypes: float64(4), int64(2), object(3)
# memory usage: 4.8+ KB

# %%
new_election = election.set_index('county')

# %%
new_election.loc["Bedford","winner"]
# Out:
# 'Romney'

# %%
new_election.loc["Bedford"]["winner"]
# Out:
# 'Romney'

# %%
results = new_election[["winner","voters","total"]]
results.head()
# Out:
#            winner  voters   total
# county
# Adams      Romney   61156   41973
# Allegheny   Obama  924351  614671
# Armstrong  Romney   42147   28322
# Beaver     Romney  115157   80015
# Bedford    Romney   32189   21444

# %%
#slicing perry to potter
p_counties = results.loc["Perry":"Potter"]
p_counties
# Out:
#               winner   voters   total
# county
# Perry         Romney    27245   18240
# Philadelphia   Obama  1099197  653598
# Pike          Romney    41840   23164
# Potter        Romney    10913    7205

# %%
#reverse order
p_counties[::-1]
# Out:
#               winner   voters   total
# county
# Potter        Romney    10913    7205
# Pike          Romney    41840   23164
# Philadelphia   Obama  1099197  653598
# Perry         Romney    27245   18240

# %%
new_election.iloc[4,4] == new_election.loc["Bedford"]["winner"]
# Out:
# True

# %%
new_election.loc[:,"Obama":].head()
# Out:
#                Obama     Romney  winner  voters    turnout     margin
# county
# Adams      35.482334  63.112001  Romney   61156  68.632677  27.629667
# Allegheny  56.640219  42.185820   Obama  924351  66.497575  14.454399
# Armstrong  30.696985  67.901278  Romney   42147  67.198140  37.204293
# Beaver     46.032619  52.637630  Romney  115157  69.483401   6.605012
# Bedford    22.057452  76.986570  Romney   32189  66.619031  54.929118

# %%
new_election.loc[:,["Obama","Romney","winner"]].head()
# Out:
#                Obama     Romney  winner
# county
# Adams      35.482334  63.112001  Romney
# Allegheny  56.640219  42.185820   Obama
# Armstrong  30.696985  67.901278  Romney
# Beaver     46.032619  52.637630  Romney
# Bedford    22.057452  76.986570  Romney

# %%
new_election.loc[:,"Romney":].head()
# Out:
#               Romney  winner  voters    turnout     margin
# county
# Adams      63.112001  Romney   61156  68.632677  27.629667
# Allegheny  42.185820   Obama  924351  66.497575  14.454399
# Armstrong  67.901278  Romney   42147  67.198140  37.204293
# Beaver     52.637630  Romney  115157  69.483401   6.605012
# Bedford    76.986570  Romney   32189  66.619031  54.929118

# %%
rows = ['Philadelphia','Centre','Fulton']
column = ['winner','Obama','Romney']
three_counties = new_election.loc[rows,column]

# %%
three_counties
# Out:
#               winner      Obama     Romney
# county
# Philadelphia   Obama  85.224251  14.051451
# Centre        Romney  48.948416  48.977486
# Fulton        Romney  21.096291  77.748861

# %%
high_turnout = new_election.turnout>70
new_election[high_turnout]
# Out:
#              state   total      Obama     Romney  winner  voters    turnout  \
# county
# Bucks           PA  319407  49.966970  48.801686   Obama  435606  73.324748
# Butler          PA   88924  31.920516  66.816607  Romney  122762  72.436096
# Chester         PA  248295  49.228539  49.650617  Romney  337822  73.498766
# Forest          PA    2308  38.734835  59.835355  Romney    3232  71.410891
# Franklin        PA   62802  30.110506  68.583803  Romney   87406  71.850903
# Montgomery      PA  401787  56.637223  42.286834   Obama  551105  72.905708
# Westmoreland    PA  168709  37.567646  61.306154  Romney  238006  70.884347
#
#                  margin
# county
# Bucks          1.165284
# Butler        34.896091
# Chester        0.422079
# Forest        21.100520
# Franklin      38.473297
# Montgomery    14.350390
# Westmoreland  23.738508

# %%
import numpy as np

# %%
#too_close = new_election[new_election.margin<1,"winner"]=np.nan
too_close = new_election[new_election.margin<1]
k = new_election[too_close]

# %%
k.winner=np.nan
k
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\generic.py:4405: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self[name] = value
#         state   total      Obama     Romney  winner  voters    turnout  \
# county
# Berks      PA  163253  48.939376  49.528646     NaN  250356  65.208343
# Centre     PA   68801  48.948416  48.977486     NaN  112949  60.913333
# Chester    PA  248295  49.228539  49.650617     NaN  337822  73.498766
#
#            margin
# county
# Berks    0.589269
# Centre   0.029069
# Chester  0.422079

# %% [markdown]
# # -------------------------------------------------------

# %%
tatanic_df = pd.read_csv("titanic.csv")
tatanic_df.head()
# Out:
#    pclass  survived                                             name     sex  \
# 0       1         1                    Allen, Miss. Elisabeth Walton  female
# 1       1         1                   Allison, Master. Hudson Trevor    male
# 2       1         0                     Allison, Miss. Helen Loraine  female
# 3       1         0             Allison, Mr. Hudson Joshua Creighton    male
# 4       1         0  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)  female
#
#      age  sibsp  parch  ticket      fare    cabin embarked boat   body  \
# 0  29.00      0      0   24160  211.3375       B5        S    2    NaN
# 1   0.92      1      2  113781  151.5500  C22 C26        S   11    NaN
# 2   2.00      1      2  113781  151.5500  C22 C26        S  NaN    NaN
# 3  30.00      1      2  113781  151.5500  C22 C26        S  NaN  135.0
# 4  25.00      1      2  113781  151.5500  C22 C26        S  NaN    NaN
#
#                          home.dest
# 0                     St Louis, MO
# ...

# %%
tatanic_df.describe()
# Out:
#             pclass     survived          age        sibsp        parch  \
# count  1309.000000  1309.000000  1046.000000  1309.000000  1309.000000
# mean      2.294882     0.381971    29.881138     0.498854     0.385027
# std       0.837836     0.486055    14.413493     1.041658     0.865560
# min       1.000000     0.000000     0.170000     0.000000     0.000000
# 25%       2.000000     0.000000    21.000000     0.000000     0.000000
# 50%       3.000000     0.000000    28.000000     0.000000     0.000000
# 75%       3.000000     1.000000    39.000000     1.000000     0.000000
# max       3.000000     1.000000    80.000000     8.000000     9.000000
#
#               fare        body
# count  1308.000000  121.000000
# mean     33.295479  160.809917
# std      51.758668   97.696922
# min       0.000000    1.000000
# 25%       7.895800   72.000000
# 50%      14.454200  155.000000
# 75%      31.275000  256.000000
# max     512.329200  328.000000

# %%
df = tatanic_df[["age","cabin"]]

# %%
tatanic_df[["age","cabin"]].isnull().sum()
# Out:
# age       263
# cabin    1014
# dtype: int64

# %%
df.shape
# Out:
# (1309, 2)

# %%
df.dropna(how="any").shape#if any nan present it will delete
# Out:
# (272, 2)

# %%
df.dropna(how="all").shape
# Out:
# (1069, 2)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1309 entries, 0 to 1308
# Data columns (total 2 columns):
# age      1046 non-null float64
# cabin    295 non-null object
# dtypes: float64(1), object(1)
# memory usage: 20.5+ KB

# %%
df.isnull().sum()
# Out:
# age       263
# cabin    1014
# dtype: int64

# %%
new_df = tatanic_df.dropna(thresh=1000,axis=1)#drop that column which columns has atleast 1000 not null value
new_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1309 entries, 0 to 1308
# Data columns (total 10 columns):
# pclass      1309 non-null int64
# survived    1309 non-null int64
# name        1309 non-null object
# sex         1309 non-null object
# age         1046 non-null float64
# sibsp       1309 non-null int64
# parch       1309 non-null int64
# ticket      1309 non-null object
# fare        1308 non-null float64
# embarked    1307 non-null object
# dtypes: float64(2), int64(4), object(4)
# memory usage: 102.3+ KB

# %% [markdown]
# # ---------------------------------1

# %%
import pandas as pd
weather_data = pd.read_csv("Pittsburgh weather data.csv")
weather_data.head()
# Out:
#        Date  Max TemperatureF  Mean TemperatureF  Min TemperatureF  \
# 0  2013-1-1                32                 28                21
# 1  2013-1-2                25                 21                17
# 2  2013-1-3                32                 24                16
# 3  2013-1-4                30                 28                27
# 4  2013-1-5                34                 30                25
#
#    Max Dew PointF  Mean Dew PointF  Min DewpointF  Max Humidity  \
# 0              30               27             16           100
# 1              14               12             10            77
# 2              19               15              9            77
# 3              21               19             17            75
# 4              23               20             16            75
#
#    Mean Humidity  Min Humidity       ...        Max VisibilityMiles  \
# 0             89            77       ...                         10
# ...

# %%
['Mean TemperatureF','Mean Dew PointF']
# Out:
# ['Mean TemperatureF', 'Mean Dew PointF']

# %%
def far_cel(F):
    C = (F - 32) * 5/9
    return C

# %%
weather_data[['Mean TemperatureF','Mean Dew PointF']].apply(far_cel).head()
# Out:
#    Mean TemperatureF  Mean Dew PointF
# 0          -2.222222        -2.777778
# 1          -6.111111       -11.111111
# 2          -4.444444        -9.444444
# 3          -2.222222        -7.222222
# 4          -1.111111        -6.666667

# %%
dict1 = {'Obama':'blue','Romney':'red'}

# %%
election.head()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-9-8dfc68af5c27> in <module>
# ----> 1 election.head()
#
# NameError: name 'election' is not defined

# %%
for column in election.columns:
    if column == "winner":
        for
# Out:
#   File "<ipython-input-10-564e7a497249>", line 3
#     for
#         ^
# SyntaxError: invalid syntax

# %%
dict1 = {'Obama':'blue','Romney':'red'}
election["color"] = election["winner"].map(dict1) 
election.head()
# Out:
#       county state   total      Obama     Romney  winner  voters    turnout  \
# 0      Adams    PA   41973  35.482334  63.112001  Romney   61156  68.632677
# 1  Allegheny    PA  614671  56.640219  42.185820   Obama  924351  66.497575
# 2  Armstrong    PA   28322  30.696985  67.901278  Romney   42147  67.198140
# 3     Beaver    PA   80015  46.032619  52.637630  Romney  115157  69.483401
# 4    Bedford    PA   21444  22.057452  76.986570  Romney   32189  66.619031
#
#       margin color
# 0  27.629667   red
# 1  14.454399  blue
# 2  37.204293   red
# 3   6.605012   red
# 4  54.929118   red

# %%
from scipy.stats import zscore

# %%
zscore(election["turnout"])
# Out:
# array([ 0.85373443,  0.43984633,  0.57565034,  1.01864668,  0.46339055,
#         0.18992961, -1.62978766, -1.67811834,  1.76328918,  1.59102463,
#         0.4115648 , -2.00690534, -0.41140691, -0.64265536,  1.79702245,
#        -0.21292049, -0.36907863, -1.76358992, -0.63882099, -0.72673199,
#         1.02421347,  0.83473876,  0.86101802, -0.58691702, -0.09392156,
#        -2.26015319,  1.39228937,  1.47758532,  0.30389161, -0.71004763,
#        -0.62292272, -0.22739249, -0.8586792 ,  1.11463935,  0.14408255,
#         1.08675066, -0.25721482,  0.3426399 , -0.04498491, -0.09489986,
#         0.71129079, -1.19644405, -0.06680477,  0.48399098, -1.89069251,
#         1.68205856, -1.28403638, -0.79798793, -1.33971045,  0.52717328,
#        -0.9241102 , -1.71852766,  0.34769042,  0.46386596,  0.99379745,
#         0.21159213,  0.95701947,  0.83419812, -0.56442943,  0.65096061,
#        -0.16243951, -1.4886646 , -0.18238803,  0.02514726,  1.29021923,
#         0.14757638,  0.44085587])

# %%
type(zscore(election["turnout"]))
# Out:
# numpy.ndarray

# %%
election["turnout_zscore"]=zscore(election["turnout"])
election.head()
# Out:
#       county state   total      Obama     Romney  winner  voters    turnout  \
# 0      Adams    PA   41973  35.482334  63.112001  Romney   61156  68.632677
# 1  Allegheny    PA  614671  56.640219  42.185820   Obama  924351  66.497575
# 2  Armstrong    PA   28322  30.696985  67.901278  Romney   42147  67.198140
# 3     Beaver    PA   80015  46.032619  52.637630  Romney  115157  69.483401
# 4    Bedford    PA   21444  22.057452  76.986570  Romney   32189  66.619031
#
#       margin color  turnout_zscore
# 0  27.629667   red        0.853734
# 1  14.454399  blue        0.439846
# 2  37.204293   red        0.575650
# 3   6.605012   red        1.018647
# 4  54.929118   red        0.463391

# %%
Series.mask(cond, other=nan, inplace=False, axis=None, level=None, errors='raise', try_cast=False, raise_on_error=None)[source]

# %% [markdown]
# # -------------------------

# %%
euro = pd.read_csv("euro_winners.csv")
euro.head()
# Out:
#     Season Nation      Winners Score           Runners-up Runner-UpNation  \
# 0  1955–56  Spain  Real Madrid   4–3       Stade de Reims          France
# 1  1956–57  Spain  Real Madrid   2–0           Fiorentina           Italy
# 2  1957–58  Spain  Real Madrid   3–2                Milan           Italy
# 3  1958–59  Spain  Real Madrid   2–0       Stade de Reims          France
# 4  1959–60  Spain  Real Madrid   7–3  Eintracht Frankfurt         Germany
#
#                                Venue  Attendance
# 0             Parc des Princes,Paris       38239
# 1  Santiago Bernabéu Stadium, Madrid      124000
# 2            Heysel Stadium,Brussels       67000
# 3            Neckarstadion,Stuttgart       72000
# 4               Hampden Park,Glasgow      127621

# %%
k = euro.groupby("Nation")
k

# %%
k.groups
# Out:
# {'England': Int64Index([12, 21, 22, 23, 24, 25, 26, 28, 43, 49, 52, 56], dtype='int64'),
#  'France': Int64Index([37], dtype='int64'),
#  'Germany': Int64Index([18, 19, 20, 27, 41, 45, 57], dtype='int64'),
#  'Italy': Int64Index([7, 8, 9, 13, 29, 33, 34, 38, 40, 47, 51, 54], dtype='int64'),
#  'Netherlands': Int64Index([14, 15, 16, 17, 32, 39], dtype='int64'),
#  'Portugal': Int64Index([5, 6, 31, 48], dtype='int64'),
#  'Romania': Int64Index([30], dtype='int64'),
#  'Scotland': Int64Index([11], dtype='int64'),
#  'Spain': Int64Index([0, 1, 2, 3, 4, 10, 36, 42, 44, 46, 50, 53, 55], dtype='int64'),
#  'Yugoslavia': Int64Index([35], dtype='int64')}

# %%
k = euro.groupby("Nation").size()
k
# Out:
# Nation
# England        12
# France          1
# Germany         7
# Italy          12
# Netherlands     6
# Portugal        4
# Romania         1
# Scotland        1
# Spain          13
# Yugoslavia      1
# dtype: int64

# %%
k.sort_values(ascending=False)
# Out:
# Nation
# Spain          13
# Italy          12
# England        12
# Germany         7
# Netherlands     6
# Portugal        4
# Yugoslavia      1
# Scotland        1
# Romania         1
# France          1
# dtype: int64

# %%
euro.groupby(["Nation","Winners"]).size().sort_values(ascending=False)
# Out:
# Nation       Winners
# Spain        Real Madrid          9
# Italy        Milan                7
# Germany      Bayern Munich        5
# England      Liverpool            5
# Spain        Barcelona            4
# Netherlands  Ajax                 4
# England      Manchester United    3
# Italy        Internazionale       3
#              Juventus             2
# Portugal     Porto                2
#              Benfica              2
# England      Nottingham Forest    2
#              Chelsea              1
# France       Marseille            1
# Yugoslavia   Red Star Belgrade    1
# Germany      Borussia Dortmund    1
#              Hamburg              1
# Netherlands  Feyenoord            1
#              PSV Eindhoven        1
# Romania      Steaua Bucure?ti     1
# Scotland     Celtic               1
# England      Aston Villa          1
# dtype: int64

# %% [markdown]
# # ------------------------

# %%
goal_df = pd.read_csv("goal_stats_euro_leagues_2012-13.csv")
goal_df.head()
new_goal = goal_df.set_index("Month")

# %%
k = goal_df.Month
k.
# Out:
# pandas.core.series.Series

# %%
goal_df['Month'].apply(lambda x : x.split("/")[1])
# Out:
# 0     01
# 1     01
# 2     01
# 3     01
# 4     01
# 5     01
# 6     01
# 7     01
# 8     01
# 9     01
# 10    02
# 11    01
# 12    01
# 13    01
# 14    01
# 15    01
# 16    01
# 17    01
# 18    01
# 19    01
# 20    01
# 21    01
# Name: Month, dtype: object

# %%
year_group = new_goal.groupby(lambda Month : Month.split("/")[2])
year_group

# %%
for year,grp in year_group:
    print(year,grp)
# Out:
# 2012                      Stat    EPL  La Liga  Serie A  Bundesliga
# Month
# 08/01/2012  MatchesPlayed   20.0       20     10.0        10.0
# 09/01/2012  MatchesPlayed   38.0       39     50.0        44.0
# 10/01/2012  MatchesPlayed   31.0       31     39.0        27.0
# 11/01/2012  MatchesPlayed   50.0       41     42.0        46.0
# 12/01/2012  MatchesPlayed   59.0       39     39.0        26.0
# 08/01/2012    GoalsScored   57.0       60     21.0        23.0
# 09/01/2012    GoalsScored  111.0      112    133.0       135.0
# 10/01/2012    GoalsScored   95.0       88     97.0        77.0
# 11/01/2012    GoalsScored  121.0      116    120.0       137.0
# 12/01/2012    GoalsScored  183.0      109    125.0        72.0
# 2013                      Stat    EPL  La Liga  Serie A  Bundesliga
# Month
# 01/01/2013  MatchesPlayed   42.0       40     40.0        18.0
# 02/01/2013  MatchesPlayed   30.0       40     40.0        36.0
# ...

# %%
grp_month = new_goal.groupby(level=0)
grp_month

# %%
for i,j in grp_month:
    print(i,j)
    print("\n")
# Out:
# 01/01/2013                      Stat    EPL  La Liga  Serie A  Bundesliga
# Month
# 01/01/2013  MatchesPlayed   42.0       40     40.0        18.0
# 01/01/2013    GoalsScored  117.0      121    104.0        51.0
#
#
# 02/01/2013                      Stat   EPL  La Liga  Serie A  Bundesliga
# Month
# 02/01/2013  MatchesPlayed  30.0       40     40.0        36.0
# 02/01/2013    GoalsScored  87.0      110    100.0       101.0
#
#
# 03/01/2013                      Stat   EPL  La Liga  Serie A  Bundesliga
# Month
# 03/01/2013  MatchesPlayed  35.0       38     39.0        36.0
# 03/01/2013    GoalsScored  91.0      101     99.0       106.0
#
#
# 04/01/2013                      Stat    EPL  La Liga  Serie A  Bundesliga
# Month
# 04/01/2013  MatchesPlayed   42.0       42     41.0        36.0
# 04/01/2013    GoalsScored  105.0      127    102.0       104.0
#
#
# 05/01/2013                      Stat   EPL  La Liga  Serie A  Bundesliga
# Month
# ...
